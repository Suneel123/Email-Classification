# %% [markdown]
# # Chatbot

# %% [markdown]
# ## Setup

# %%
import glob
import re
import unicodedata
import codecs

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %matplotlib inline

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
in_files = glob.glob('../data/processed/*')

# %%
in_files
# Out:
# ['../data/processed/ChequeManagement.txt',
#  '../data/processed/ChequesManagement_full.txt',
#  '../data/processed/ChequeStatus.txt',
#  '../data/processed/IssueOfCheques.txt',
#  '../data/processed/StoppedCheque.txt',
#  '../data/processed/SweepConditionExample.txt',
#  '../data/processed/SweepInstructions.txt',
#  '../data/processed/SweepInstructions_full.txt']

# %%
tmp_list = []

for filepath in in_files:
    file = filepath.rsplit('/', 2)[-1]
    filename = file.split('.')[0]
    with codecs.open(filepath, 'r', encoding='utf-8', errors='ignore') as file_obj:
        content = file_obj.read()
    tmp_list.append({'FAQ_answer': content, 'FAQ_question': filename})    
    print(f'Reading {file} completed...')
# Out:
# Reading ChequeManagement.txt completed...
# Reading ChequesManagement_full.txt completed...
# Reading ChequeStatus.txt completed...
# Reading IssueOfCheques.txt completed...
# Reading StoppedCheque.txt completed...
# Reading SweepConditionExample.txt completed...
# Reading SweepInstructions.txt completed...
# Reading SweepInstructions_full.txt completed...

# %%
input_df = pd.DataFrame(tmp_list)

# %%
input_df
# Out:
#                                           FAQ_answer            FAQ_question
# 0  Cheque Management\n---------------------------...        ChequeManagement
# 1  Cheque Management\r\n-------------------------...  ChequesManagement_full
# 2  Cheque Status\n-----------------\nYou can enqu...            ChequeStatus
# 3  Issue of Cheques\n-------------------------\nY...          IssueOfCheques
# 4  Stopped Cheque\n-------------------\nYou can s...           StoppedCheque
# 5  Sweep condition examples:\n(These are the thre...   SweepConditionExample
# 6  Sweep Instructions\n------------------\nStandi...       SweepInstructions
# 7  Sweep Instructions\r\n\r\nStanding instruction...  SweepInstructions_full

# %%
def clean(faq):
    faq = re.sub(r'[^A-Za-z]', " ", faq)
    faq = re.sub(r"\s{2,}", " ", faq)
    faq = faq.split()
    ps = nltk.PorterStemmer()
    faq = [ps.stem(word) for word in faq]
    faq = [word for word in faq if word not in STOPWORDS]
    faq = ' '.join(faq)
    return faq

# %%
input_df['FAQ_answer_cleaned'] = input_df['FAQ_answer'].apply(clean)

# %%
for row in input_df.itertuples():
    print(f'{row.FAQ_question}:-\n{row.FAQ_answer_cleaned}\n')
# Out:
# ChequeManagement:-
# chequ manag bankfair allow issu chequ custom transact account chequ cannot issu fix instal account debit made chequ transact mechan ensur chequ number pertain concern account alreadi paid payment chequ ha stop
#
# ChequesManagement_full:-
# chequ manag bankfair allow issu chequ custom transact account chequ cannot issu fix instal account debit made chequ transact mechan ensur chequ number pertain concern account alreadi paid payment chequ ha stop issu chequ issu singl chequ chequ book transact account defin number leav chequ book contain defin sever chequ book differ number leav chequ number ha numer issu chequ book enough indic begin number chequ book system creat remain number take account number leav chequ book contain chequ number uniqu specifi charg ha collect per chequ leaf system calcul charg total number chequ issu chequ statu enquir statu particular chequ chequ issu account differ statu unpaid paid return stop issu chequ ha unpaid statu thi statu last till chequ paid return unpaid A chequ return unpaid subsequ paid gain statu paid stop chequ stop payment issu chequ rang chequ give stop instruct system doe valid Do chequ belong indic account still unpaid captur follow inform stop chequ chequ number currenc amount date benefuciari name captur follow inform stop seri chequ chequ begin number chequ end number system produc acknowledg custom inform record stop instruct eod view stop instruct particular account stop instruct held system revok stop instruct whenev want
#
# ChequeStatus:-
# chequ statu enquir statu particular chequ chequ issu account differ statu unpaid paid return stop issu chequ ha unpaid statu thi statu last till chequ paid return unpaid A chequ return unpaid subsequ paid gain statu paid
#
# IssueOfCheques:-
# issu chequ issu singl chequ chequ book transact account defin number leav chequ book contain defin sever chequ book differ number leav chequ number ha numer issu chequ book enough indic begin number chequ book system creat remain number take account number leav chequ book contain chequ number uniqu specifi charg ha collect per chequ leaf system calcul charg total number chequ issu
#
# StoppedCheque:-
# stop chequ stop payment issu chequ rang chequ give stop instruct system doe valid Do chequ belong indic account still unpaid captur follow inform stop chequ chequ number currenc amount date benefuciari name captur follow inform stop seri chequ chequ begin number chequ end number system produc acknowledg custom inform record stop instruct eod view stop instruct particular account stop instruct held system revok stop instruct whenev want
#
# SweepConditionExample:-
# sweep condit exampl three variant SO If clear balanc exce bzd account Id transfer amount excess bzd account Id If balanc goe bzd account Id transfer money account Id amount transfer bzd clear balanc account Id thi amount debit account Id credit account Id balanc account Id becom bzd If neg balanc exce bzd account Id transfer money account Id amount transfer neg clear balanc bzd thi amount debit account Id credit account Id balanc account Id becom bzd everi SO ha Id thi Id mention transact narrat
#
# SweepInstructions:-
# sweep instruct stand instruct cater specif amount specif date certain custom may want amount transfer one account anoth balanc account exceed particular level balanc go certain level instruct refer sweep instruct sweep instruct involv transact account applic instal fix deposit account sweep instruct SO A begin date execut An end date execut condit sweep clear balanc exceed level balanc dip level book balanc avail balanc consid stand instruct sweep instruct account receiv credit debit frequenc execut daili wekli monthli quarterli half yearli yearli next due date execut sweep instruct charg counter indic number time execut ha taken place taken place instruct modifi delet without ani restrict
#
# SweepInstructions_full:-
# sweep instruct stand instruct cater specif amount specif date certain custom may want amount transfer one account anoth balanc account exceed particular level balanc go certain level instruct refer sweep instruct sweep instruct involv transact account applic instal fix deposit account sweep instruct SO A begin date execut An end date execut condit sweep clear balanc exceed level balanc dip level book balanc avail balanc consid stand instruct sweep instruct account receiv credit debit frequenc execut daili wekli monthli quarterli half yearli yearli next due date execut sweep instruct charg counter indic number time execut ha taken place taken place instruct modifi delet without ani restrict sweep condit exampl three variant SO If clear balanc exce bzd account Id transfer amount excess bzd account Id If balanc goe bzd account Id transfer money account Id amount transfer bzd clear balanc account Id thi amount debit account Id credit account Id balanc account Id becom bzd If neg balanc exce bzd account Id transfer money account Id amount transfer neg clear balanc bzd thi amount debit account Id credit account Id balanc account Id becom bzd everi SO ha Id thi Id mention transact narrat

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
X = vectorizer.fit_transform(input_df['FAQ_answer_cleaned'])

# %%
vectorizer.get_feature_names()
# Out:
# ['account',
#  'account alreadi',
#  'account anoth',
#  'account applic',
#  'account chequ',
#  'account debit',
#  'account defin',
#  'account differ',
#  'account exceed',
#  'account id',
#  'account number',
#  'account receiv',
#  'account still',
#  'account stop',
#  'account sweep',
#  'acknowledg',
#  'acknowledg custom',
#  'allow',
#  'allow issu',
#  'alreadi',
#  'alreadi paid',
#  'amount',
#  'amount date',
#  'amount debit',
#  'amount excess',
#  'amount specif',
#  'amount transfer',
#  'an',
#  'an end',
#  'ani',
#  'ani restrict',
#  'anoth',
#  'anoth balanc',
#  'applic',
#  'applic instal',
#  'avail',
#  'avail balanc',
#  'balanc',
#  'balanc account',
#  'balanc avail',
#  'balanc bzd',
#  'balanc consid',
#  'balanc dip',
#  'balanc exce',
#  'balanc exceed',
#  'balanc go',
#  'balanc goe',
#  'bankfair',
#  'bankfair allow',
#  'becom',
#  'becom bzd',
#  'begin',
#  'begin date',
#  'begin number',
#  'belong',
#  'belong indic',
#  'benefuciari',
#  'benefuciari name',
#  'book',
#  'book balanc',
#  'book contain',
#  'book differ',
#  'book enough',
#  'book system',
#  'book transact',
#  'bzd',
#  'bzd account',
#  'bzd clear',
#  'bzd everi',
#  'bzd if',
#  'bzd thi',
#  'calcul',
#  'calcul charg',
#  'cannot',
#  'cannot issu',
#  'captur',
#  'captur follow',
#  'cater',
#  'cater specif',
#  'certain',
#  'certain custom',
#  'certain level',
#  'charg',
#  'charg counter',
#  'charg ha',
#  'charg total',
#  'chequ',
#  'chequ begin',
#  'chequ belong',
#  'chequ book',
#  'chequ cannot',
#  'chequ chequ',
#  'chequ custom',
#  'chequ end',
#  'chequ give',
#  'chequ ha',
#  'chequ issu',
#  'chequ leaf',
#  'chequ manag',
#  'chequ number',
#  'chequ paid',
#  'chequ rang',
#  'chequ return',
#  'chequ statu',
#  'chequ stop',
#  'chequ transact',
#  'clear',
#  'clear balanc',
#  'collect',
#  'collect per',
#  'concern',
#  'concern account',
#  'condit',
#  'condit exampl',
#  'condit sweep',
#  'consid',
#  'consid stand',
#  'contain',
#  'contain chequ',
#  'contain defin',
#  'counter',
#  'counter indic',
#  'creat',
#  'creat remain',
#  'credit',
#  'credit account',
#  'credit debit',
#  'currenc',
#  'currenc amount',
#  'custom',
#  'custom inform',
#  'custom may',
#  'custom transact',
#  'daili',
#  'daili wekli',
#  'date',
#  'date benefuciari',
#  'date certain',
#  'date execut',
#  'debit',
#  'debit account',
#  'debit frequenc',
#  'debit made',
#  'defin',
#  'defin number',
#  'defin sever',
#  'delet',
#  'delet without',
#  'deposit',
#  'deposit account',
#  'differ',
#  'differ number',
#  'differ statu',
#  'dip',
#  'dip level',
#  'do',
#  'do chequ',
#  'doe',
#  'doe valid',
#  'due',
#  'due date',
#  'end',
#  'end date',
#  'end number',
#  'enough',
#  'enough indic',
#  'enquir',
#  'enquir statu',
#  'ensur',
#  'ensur chequ',
#  'eod',
#  'eod view',
#  'everi',
#  'everi so',
#  'exampl',
#  'exampl three',
#  'exce',
#  'exce bzd',
#  'exceed',
#  'exceed level',
#  'exceed particular',
#  'excess',
#  'excess bzd',
#  'execut',
#  'execut an',
#  'execut condit',
#  'execut daili',
#  'execut ha',
#  'execut sweep',
#  'fix',
#  'fix deposit',
#  'fix instal',
#  'follow',
#  'follow inform',
#  'frequenc',
#  'frequenc execut',
#  'gain',
#  'gain statu',
#  'give',
#  'give stop',
#  'go',
#  'go certain',
#  'goe',
#  'goe bzd',
#  'ha',
#  'ha collect',
#  'ha id',
#  'ha numer',
#  'ha stop',
#  'ha taken',
#  'ha unpaid',
#  'half',
#  'half yearli',
#  'held',
#  'held system',
#  'id',
#  'id amount',
#  'id balanc',
#  'id becom',
#  'id credit',
#  'id if',
#  'id mention',
#  'id thi',
#  'id transfer',
#  'if',
#  'if balanc',
#  'if clear',
#  'if neg',
#  'indic',
#  'indic account',
#  'indic begin',
#  'indic number',
#  'inform',
#  'inform record',
#  'inform stop',
#  'instal',
#  'instal account',
#  'instal fix',
#  'instruct',
#  'instruct account',
#  'instruct cater',
#  'instruct charg',
#  'instruct eod',
#  'instruct held',
#  'instruct involv',
#  'instruct modifi',
#  'instruct particular',
#  'instruct refer',
#  'instruct so',
#  'instruct stand',
#  'instruct sweep',
#  'instruct system',
#  'instruct whenev',
#  'involv',
#  'involv transact',
#  'issu',
#  'issu account',
#  'issu chequ',
#  'issu fix',
#  'issu singl',
#  'last',
#  'last till',
#  'leaf',
#  'leaf system',
#  'leav',
#  'leav chequ',
#  'level',
#  'level balanc',
#  'level book',
#  'level instruct',
#  'made',
#  'made chequ',
#  'manag',
#  'manag bankfair',
#  'may',
#  'may want',
#  'mechan',
#  'mechan ensur',
#  'mention',
#  'mention transact',
#  'modifi',
#  'modifi delet',
#  'money',
#  'money account',
#  'monthli',
#  'monthli quarterli',
#  'name',
#  'name captur',
#  'narrat',
#  'neg',
#  'neg balanc',
#  'neg clear',
#  'next',
#  'next due',
#  'number',
#  'number chequ',
#  'number currenc',
#  'number ha',
#  'number leav',
#  'number pertain',
#  'number system',
#  'number take',
#  'number time',
#  'number uniqu',
#  'numer',
#  'numer issu',
#  'one',
#  'one account',
#  'paid',
#  'paid gain',
#  'paid payment',
#  'paid return',
#  'paid stop',
#  'particular',
#  'particular account',
#  'particular chequ',
#  'particular level',
#  'payment',
#  'payment chequ',
#  'payment issu',
#  'per',
#  'per chequ',
#  'pertain',
#  'pertain concern',
#  'place',
#  'place instruct',
#  'place taken',
#  'produc',
#  'produc acknowledg',
#  'quarterli',
#  'quarterli half',
#  'rang',
#  'rang chequ',
#  'receiv',
#  'receiv credit',
#  'record',
#  'record stop',
#  'refer',
#  'refer sweep',
#  'remain',
#  'remain number',
#  'restrict',
#  'restrict sweep',
#  'return',
#  'return stop',
#  'return unpaid',
#  'revok',
#  'revok stop',
#  'seri',
#  'seri chequ',
#  'sever',
#  'sever chequ',
#  'singl',
#  'singl chequ',
#  'so',
#  'so begin',
#  'so ha',
#  'so if',
#  'specif',
#  'specif amount',
#  'specif date',
#  'specifi',
#  'specifi charg',
#  'stand',
#  'stand instruct',
#  'statu',
#  'statu enquir',
#  'statu last',
#  'statu paid',
#  'statu particular',
#  'statu thi',
#  'statu unpaid',
#  'still',
#  'still unpaid',
#  'stop',
#  'stop chequ',
#  'stop instruct',
#  'stop issu',
#  'stop payment',
#  'stop seri',
#  'subsequ',
#  'subsequ paid',
#  'sweep',
#  'sweep clear',
#  'sweep condit',
#  'sweep instruct',
#  'system',
#  'system calcul',
#  'system creat',
#  'system doe',
#  'system produc',
#  'system revok',
#  'take',
#  'take account',
#  'taken',
#  'taken place',
#  'thi',
#  'thi amount',
#  'thi id',
#  'thi statu',
#  'three',
#  'three variant',
#  'till',
#  'till chequ',
#  'time',
#  'time execut',
#  'total',
#  'total number',
#  'transact',
#  'transact account',
#  'transact mechan',
#  'transact narrat',
#  'transfer',
#  'transfer amount',
#  'transfer bzd',
#  'transfer money',
#  'transfer neg',
#  'transfer one',
#  'uniqu',
#  'uniqu specifi',
#  'unpaid',
#  'unpaid captur',
#  'unpaid chequ',
#  'unpaid paid',
#  'unpaid statu',
#  'unpaid subsequ',
#  'valid',
#  'valid do',
#  'variant',
#  'variant so',
#  'view',
#  'view stop',
#  'want',
#  'want amount',
#  'wekli',
#  'wekli monthli',
#  'whenev',
#  'whenev want',
#  'without',
#  'without ani',
#  'yearli',
#  'yearli next',
#  'yearli yearli']

# %%
def similarity(test):
    test = clean(test)
    test = vectorizer.transform([test])
    similarity_score = cosine_similarity(X, test)
    faq_idx = np.argmax(similarity_score)
    return similarity_score, faq_idx

# %%
test1 = 'How to issue check?'
test2 = 'What is Sweep?'
test3 = 'Can you give some examples for sweep conditions'
test4 = 'What are different statuses of cheques? '

# %%
similarity_scores, faq_idx = similarity(test2)
print(input_df.iloc[faq_idx]['FAQ_answer'])
# Out:
# Sweep Instructions
# ------------------
# Standing instructions cater to specific amounts and specific dates. But certain customers may want amounts to be transferred from one account to another if the balance in the accounts exceed a particular level or when the balances go below a certain level. Such instructions are referred to as Sweep Instructions.
# Sweep Instructions involve Transaction accounts. They are not applicable to Installment or Fixed Deposits accounts.
#
# Sweep instructions (SO) have -
# A Begin date for execution
# An End date for execution
# Condition for sweep - clear balance exceeding a level or balance dipping below a level
# (book balance and available balance are not considered for Standing Instructions or Sweep Instructions).
# Accounts that receives credit and debit
# Frequency of Execution - daily, wekly, monthly,quarterly, half yearly and yearly
# Next due date for execution
# Sweep Instruction charges
# Counters that indicates the number of times the execution has taken place and not taken place.
#
# Instructions can be modified or deleted without any restrictions.

# %%
similarity_scores
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.03159785],
#        [0.30499316],
#        [0.19255778]])

# %%
print(input_df.iloc[5]['FAQ_answer'])
# Out:
# Sweep condition examples:
# (These are the three variants of SO)
# 1. If (Clear) Balance exceeds BZD 50000 in Account Id 123, transfer amounts in excess of BZD 50000 to Account Id 345.
#
# 2. If balance goes below BZD 10000 in Account Id 345, transfer money from Account Id657.
# (Amount transferred will be BZD10000 - Clear Balance in Account Id 345).
# This amount is debited to Account Id 657 and Credited to account Id 345; balance in account Id 345 now becomes BZD10000.
#
# 3. If negative balance exceeds BZD20000 in Account Id345,  transfer money from Account Id657.
# (Amount transferred will be negative Clear Balance - BZD10000).
# This amount is debited to Account Id 657 and Credited to account Id 345; balance in account Id 345 now becomes BZD10000.
#
# Every SO has an Id.
# This Id is mentioned in the transaction narration.
